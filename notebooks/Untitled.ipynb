# %%
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import display, Image

# %%
import pandas as pd
import gzip
import io

# %%
PLANETS_ORB_ELEMENTS_AFN='/home/benito/PERSONAL/practical-astronomy/data/planets.csv'
NUMBERED_ASTERIODS_AFN='/home/benito/PERSONAL/practical-astronomy/data/ELEMENTS.NUMBR.gz'
COMETS_AFN = '/home/benito/PERSONAL/practical-astronomy/data/ELEMENTS.COMET.gz'
fn=COMETS_AFN

# %%
with gzip.open(COMETS_AFN, 'rt') as f:
    file_content = io.StringIO(f.read())

# %%
headers = []
ranges = None
with gzip.open(fn,'rt') as f:
    for idx, line in enumerate(f):
        if idx == 0:
            headers = filter(lambda tok: len(tok)!=0, line.strip().split(' '))
        elif idx == 1:
            ranges = filter(lambda tok: len(tok)!=0, line.strip().split(' '))
        else :
            break
    file_content = io.StringIO(f.read())
headers = list(headers)[1:] 
fro = 0
col_specs =[]
for tok in ranges:
    to = fro+len(tok)
    col_specs.append((fro,to))
    fro = to+1
df = pd.read_fwf(file_content, names=headers, header=None, dtype = {"Tp":object}, colspecs=col_specs,skiprows=[0,1])

# %%
df
# Out:
#                        Name  Epoch         q         e          i          w  \
# 0                   4P/Faye  57262  1.651876  0.569618    9.07029  205.12582
# 1                5D/Brorsen   7440  0.589847  0.809796   29.38210   14.94680
# 2               6P/d'Arrest  57200  1.361455  0.611422   19.48168  178.11523
# 3          7P/Pons-Winnecke  53379  1.256234  0.634352   22.29644  172.25788
# 4                 8P/Tuttle  54374  1.027117  0.819800   54.98318  207.50925
# ...                     ...    ...       ...       ...        ...        ...
# 3625  C/2020 H3 (Wierzchos)  58966  2.286130  0.960578   62.52983   31.08001
# 3626    C/2020 H4 (Leonard)  58965  0.940594  1.001407   84.33604  116.44768
# 3627   C/2020 H5 (Robinson)  58967  9.403570  0.942639   70.00866  317.57569
# 3628      C/2020 H6 (ATLAS)  58967  4.674037  1.009228   79.82717   20.70597
# 3629     C/2020 J1 (SONEAR)  58972  3.207467  1.063884  142.17320  344.64352
#
#            Node              Tp          Ref
# ...

# %%
from matplotlib import animation
from IPython.display import HTML

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 1), ylim=(-6, 10))
line, = ax.plot([], [], lw=1)

# Initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# Animation function which updates figure data.  This is called sequentially
def animate(i):
    line.set_data(x, u[i,:])
    return line,

# Call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=30, interval=20, blit=True)

plt.close(anim._fig)

# Call function to display the animation
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d4f0ce6146bc> in <module>
#      24
#      25 # Call function to display the animation
# ---> 26 HTML(anim.to_html5_video())
#
# ~/apps/anaconda3/envs/py37astro/lib/python3.7/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1330                                 bitrate=rcParams['animation.bitrate'],
#    1331                                 fps=1000. / self._interval)
# -> 1332                 self.save(str(path), writer=writer)
#    1333                 # Now open and base64 encode.
#    1334                 vid64 = base64.encodebytes(path.read_bytes())
#
# ~/apps/anaconda3/envs/py37astro/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
# ...
